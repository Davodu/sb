# %%
import os
from glob import glob
import cv2
from tqdm import tqdm_notebook

from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
# Out:
# Using TensorFlow backend.

# %%
#select desired categories from top
classes = ['Anorak',
 'Blouse',
 'Bomber',
 'Cardigan',
 'Jacket',
 'Parka',
 'Sweater',
 'Tank',
 'Tee']

# %%
images_path = os.path.abspath('./dataset/Img/img')

# useful for getting number of classes
Anorak_folders = glob(images_path + '/*Anorak/*')

class_images_dict = {}
for c in classes:
    class_images_dict[c] = glob(images_path + '/*{0}/*'.format(c))
class_images_dict.keys()
# Out:
# dict_keys(['Blouse', 'Cardigan', 'Parka', 'Tee', 'Tank', 'Jacket', 'Sweater', 'Anorak', 'Bomber'])

# %%
def mkdir(p):
    if not os.path.exists(p):
        os.mkdir(p)

def link(src, dst):
    if not os.path.exists(dst):
        os.symlink(src, dst)

mkdir('./dataset/modified_new')

# %%
plt.imshow(image.img_to_array(image.load_img(np.random.choice(class_images_dict['Tank']))).astype('uint8'))
plt.show()

# %%
new_category_map = {'Anorak':'0','bomber':'0','Jacket':'0','Parka':'0', #Anorak, bomber, jacket,parka
                    'Cardigan':'1', #Cardigan
                    'Sweater':'2',#sweater
                    'Tank':'3',#Tank
                    'Blouse':'4',#blouse
                    'Tee':'5'#Tee
                   }

# %%
total_images = []
for c in class_images_dict.keys():
    cur_class_list = class_images_dict[c]
    temp_array = []
    for idx,img_path in enumerate(cur_class_list[:5000]):
        temp = cur_class_list[idx]
        #cur_class_list[idx]= img_path+'+'+ new_category_map[c]
        temp = img_path + '+' + new_category_map[c]
        temp_array.append(temp)
    total_images += temp_array

# %%
total_images = shuffle(total_images)

# %%
len(total_images)
# Out:
# 30836

# %%
total_images = [item.split('+') for item in total_images]

# %%
total_images[:5]
# Out:
# [['/home/daviesodu/sb-capstone/dataset/Img/img/Layered_Watercolor_Print_Burnout_Tee/img_00000025.jpg',
#   '5'],
#  ['/home/daviesodu/sb-capstone/dataset/Img/img/Mineral_Wash_Ribbed_Tank/img_00000013.jpg',
#   '3'],
#  ['/home/daviesodu/sb-capstone/dataset/Img/img/High-Neck_Blouse/img_00000046.jpg',
#   '4'],
#  ['/home/daviesodu/sb-capstone/dataset/Img/img/Heathered_Knit_Jacket/img_00000030.jpg',
#   '0'],
#  ['/home/daviesodu/sb-capstone/dataset/Img/img/Beaded_Laser-Cut_Blouse/img_00000085.jpg',
#   '4']]

# %%
X_t,y_t = zip(*total_images)

# %%
#X_tt = X_t[:500]
#y_tt = y_t[:500]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_t, y_t, test_size=0.33, random_state=42)

# %%
len(X_train)
# Out:
# 20660

# %%
train_path_from = os.path.abspath('./dataset/Img/img/')
valid_path_from = os.path.abspath('./dataset/Img/img/')

train_path_to = os.path.abspath('./dataset/modified_new/Training')
valid_path_to = os.path.abspath('./dataset/modified_new/Validation')

mkdir(train_path_to)
mkdir(valid_path_to)

# %%
arr = glob('./dataset/modified_new/Training/*/*')
for a in arr:
    os.unlink(a)
print()

# %%
for img_path in X_train:
    img_class=img_path.split('/')[7].split('_')[-1]
    src = img_path
    dst = train_path_to + '/' + new_category_map[img_class] + '/'+ ''.join(img_path.split('/')[7:])
    if os.path.exists(src):
        link(src, dst)
    else:
        os.unlink(dst)

# %%
for img_path in X_test:
    img_class=img_path.split('/')[7].split('_')[-1]
    src = img_path
    dst = valid_path_to +'/' + new_category_map[img_class] + '/'+ ''.join(img_path.split('/')[7:])
    if os.path.exists(src):
        link(src, dst)
    else:
        os.unlink(dst)

# %%
len(X_test)
# Out:
# 10176

# %%
#glob('./dataset/modified_new/Training/*/*')

# %%
train_links = glob('./dataset/modified_new/Training/*/*')
val_links = glob('./dataset/modified_new/Validation/*/*')
assert(len(train_links)==len(X_train))
assert(len(val_links)==len(X_test))

# %%
p = X_train[0]
imgg = image.img_to_array(image.load_img(p))
imgg.shape
# Out:
# (301, 244, 3)

# %%
#glob('/home/daviesodu/sb-capstone/dataset/modified_new/Training/0/*')

# %% [markdown]
# ## Image cropping and generator instantiation

# %%
# re-size all the images to this
#IMAGE_SIZE = [100, 100]
IMAGE_SIZE = [100, 100]

# training config:
epochs = 10
batch_size = 128

# useful for getting number of files
image_files = glob(train_path_to +'//*//*.jp*g')
valid_image_files = glob(valid_path_to + '//*//*.jp*g')

# %%
# create an instance of ImageDataGenerator
gen = ImageDataGenerator(
  rescale=1./255,
  rotation_range=20,
  width_shift_range=0.1,
  height_shift_range=0.1,
  shear_range=0.1,
  zoom_range=0.2,
  horizontal_flip=True,
  vertical_flip=True,
  preprocessing_function=preprocess_input
)

# %%
def get_bbox(bbox_file_path):
    rf = open(bbox_file_path).readlines()[2:]
    
    bboxes = {}
    for l in tqdm_notebook(range(len(rf))):
        info = rf[l].strip('\n').split(' ')
        img_path = '/home/daviesodu/sb-capstone/dataset/Img/'+info[0]
        bbox = info[-4:]
        bboxes[img_path]=[int(val) for val in bbox]
    return bboxes

# %%
def create_rescaled_bbox(bboxes, tot_paths):
    #bboxes - map of img_path->bbox
    #use img_path to get img_dimension
    #add entry of new_bbox to each image
    for k,v in tqdm_notebook(bboxes.items()):
        bbox = v
        if k in tot_paths:
            try:
                img = image.img_to_array(image.load_img(k))
                old_y, old_x, _= img.shape
                r_x = 256/old_x
                r_y=256/old_y
                new_bbox =  [bbox[0]*r_x, bbox[1]*r_y, bbox[2]*r_x, bbox[3]*r_y]
                bboxes[k] += new_bbox
            except:
                pass
    return bboxes

# %%
bboxes= get_bbox('./dataset/Anno/list_bbox.txt')
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=289222.0), HTML(value='')))

# %%
train_data = glob('./dataset/modified_new/Training/*/*')
val_data = glob('./dataset/modified_new/Validation/*/*')
tot_paths = train_data+val_data
tot_paths = [os.readlink(p) for p in tot_paths]

# %%
scaled_bboxes = create_rescaled_bbox(bboxes, tot_paths)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:24: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=289222.0), HTML(value='')))

# %%
def random_crop(img, bbox, image_dim):
    # Note: image_data_format is 'channel_last'
    assert img.shape[2] == 3
    x_1, y_1, x_2, y_2 = bbox
    
    # resize bounding box, first get scale ratio
    x_scale = image_dim / img.shape[1]
    y_scale = image_dim / img.shape[0]
    
    img = cv2.resize(img, (image_dim,image_dim), cv2.INTER_CUBIC)
    #img = img/255.0
    
    #print(x_scale,y_scale)
    
    x_1=int(np.round(x_1*x_scale))
    y_1=int(np.round(y_1*y_scale))
    x_2=int(np.round(x_2*x_scale))
    y_2=int(np.round(y_2*y_scale))
    
    #print(img.shape)
    
    img_crop = img[y_1: y_2, x_1:x_2]
    img_crop = cv2.resize(img_crop, (image_dim,image_dim), cv2.INTER_CUBIC)
    return img_crop

# %%
def drawBox(img, bbb):
    x_1, y_1, x_2, y_2 = bbb
    plt.imshow(img)
    plt.gca().add_patch(Rectangle((x_1,y_2),x_2-x_1,y_1-y_2,linewidth=1,edgecolor='r',facecolor='none'))
    plt.show()

# %%
#path = '/home/daviesodu/sb-capstone/dataset/Img/img/1981_Graphic_Ringer_Tee/img_00000001.jpg'
path = tot_paths[1]
bbb = [40, 63, 167, 246]
imgg = cv2.imread(path)
old_y, old_x, _= imgg.shape
r_x = 256/old_x
r_y=256/old_y
imgg = cv2.resize(imgg, (256,256), cv2.INTER_CUBIC)

# %%
#bbb =  [51*r_x, 84*r_y, 167*r_x, 235*r_y]
bbb
# Out:
# [40, 63, 167, 246]

# %%
bbb = scaled_bboxes[path][4:]
bbb
# Out:
# [83.62666666666667, 10.24, 174.93333333333334, 124.58666666666667]

# %%
newImg = random_crop(imgg,bbb,100)

# %% [markdown]
# ## Rewrite bounding box according to new ratio

# %%
plt.imshow(newImg)

# %%
drawBox(imgg,bbb)

# %% [markdown]
# ## Test crop method

# %%
def crop_generator(batches, bboxes, image_dim):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    """
    bbox_index = 0
    
    while True:
        batch_x, batch_y = next(batches) 
        l = batch_x.shape[0] #20
        bboxes_batch = bboxes[bbox_index:bbox_index+l] #[0:20],[20:40]
        bbox_index = l
        batch_crops = np.zeros((batch_x.shape[0], image_dim, image_dim, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], bboxes_batch[i][4:], image_dim)
        yield (batch_crops, batch_y)

# %% [markdown]
# ## Load bounding box information

# %%
# test generator to see how it works and some other useful things

# get label mapping for confusion matrix plot later
test_gen = gen.flow_from_directory(valid_path_to)
labels = [None] * len(test_gen.class_indices)
for k, v in test_gen.class_indices.items():
    labels[v] = k
# Out:
# Found 10176 images belonging to 6 classes.

# %%
def get_path_bbox(symlink_dest_array, bboxes):
    #res contains a list of bboxes, ordered according to train or test data
    res =[]
    for dest in symlink_dest_array:
        src_path=os.readlink(dest)
        bbox = bboxes[src_path]
        res.append(bbox)
    return res

# %%
val_bboxes = get_path_bbox(val_links,scaled_bboxes)
train_bboxes = get_path_bbox(train_links,scaled_bboxes)

# %%
test_crops = crop_generator(test_gen,val_bboxes, IMAGE_SIZE[0])

# %%
len(train_bboxes)
# Out:
# 20660

# %%
# should be a strangely colored image (due to VGG weights being BGR)
for x, y in test_crops:
    print('here')
    print("min:", x[0].min(), "max:", x[0].max())
    plt.title(labels[np.argmax(y[0])])
    print(x[0].shape)
    plt.imshow(x[0])
    plt.show()
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# here
# min: -0.28534865379333496 max: 0.5923961400985718
# (100, 100, 3)

# %%
# create generators
train_generator = gen.flow_from_directory(
  train_path_to,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
valid_generator = gen.flow_from_directory(
  valid_path_to,
  target_size=IMAGE_SIZE,
  shuffle=True,
  batch_size=batch_size,
)
# Out:
# Found 20660 images belonging to 6 classes.
# Found 10176 images belonging to 6 classes.

# %% [markdown]
# # Compile Model

# %%
# add preprocessing layer to the front of VGG
vgg = VGG16(input_shape=IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# %%
# don't train existing weights
for layer in vgg.layers:
    layer.trainable = False

# %%
# our layers - you can add more if you want
x = Flatten()(vgg.output)
# x = Dense(1000, activation='relu')(x)
prediction = Dense(6, activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=vgg.input, outputs=prediction)

# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='rmsprop',
  metrics=['accuracy']
)

# %% [markdown]
# # fit model

# %%
# fit the model
r = model.fit_generator(
  train_generator,
  validation_data=valid_generator,
  epochs=20,
  steps_per_epoch=len(image_files) // batch_size,
  validation_steps=len(valid_image_files) // batch_size,
)
# Out:
# Epoch 1/20
# 161/161 [==============================] - 97s 603ms/step - loss: 1.6339 - accuracy: 0.3346 - val_loss: 1.4321 - val_accuracy: 0.3974
# Epoch 2/20
# 161/161 [==============================] - 96s 598ms/step - loss: 1.5122 - accuracy: 0.3960 - val_loss: 1.5117 - val_accuracy: 0.4141
# Epoch 3/20
# 161/161 [==============================] - 96s 595ms/step - loss: 1.4815 - accuracy: 0.4111 - val_loss: 1.4192 - val_accuracy: 0.4336
# Epoch 4/20
# 161/161 [==============================] - 95s 591ms/step - loss: 1.4532 - accuracy: 0.4274 - val_loss: 1.5122 - val_accuracy: 0.4176
# Epoch 5/20
# 161/161 [==============================] - 95s 589ms/step - loss: 1.4448 - accuracy: 0.4286 - val_loss: 1.5929 - val_accuracy: 0.4280
# Epoch 6/20
# 161/161 [==============================] - 95s 590ms/step - loss: 1.4293 - accuracy: 0.4411 - val_loss: 1.3440 - val_accuracy: 0.4160
# Epoch 7/20
# 161/161 [==============================] - 95s 588ms/step - loss: 1.4287 - accuracy: 0.4377 - val_loss: 1.2810 - val_accuracy: 0.4604
# Epoch 8/20
# 161/161 [==============================] - 94s 586ms/step - loss: 1.4232 - accuracy: 0.4477 - val_loss: 1.4181 - val_accuracy: 0.4263
# Epoch 9/20
# 161/161 [==============================] - 94s 584ms/step - loss: 1.4112 - accuracy: 0.4481 - val_loss: 1.4454 - val_accuracy: 0.4145
# Epoch 10/20
# 161/161 [==============================] - 94s 583ms/step - loss: 1.4019 - accuracy: 0.4559 - val_loss: 1.7349 - val_accuracy: 0.4288
# Epoch 11/20
# 161/161 [==============================] - 93s 579ms/step - loss: 1.3939 - accuracy: 0.4548 - val_loss: 1.3602 - val_accuracy: 0.4429
# Epoch 12/20
# 161/161 [==============================] - 93s 579ms/step - loss: 1.3991 - accuracy: 0.4566 - val_loss: 1.5931 - val_accuracy: 0.4227
# Epoch 13/20
# 161/161 [==============================] - 93s 577ms/step - loss: 1.4003 - accuracy: 0.4541 - val_loss: 1.5412 - val_accuracy: 0.4467
# Epoch 14/20
# 161/161 [==============================] - 93s 575ms/step - loss: 1.3883 - accuracy: 0.4624 - val_loss: 1.7073 - val_accuracy: 0.4344
# Epoch 15/20
# 161/161 [==============================] - 93s 576ms/step - loss: 1.3926 - accuracy: 0.4637 - val_loss: 1.4223 - val_accuracy: 0.4161
# Epoch 16/20
# 161/161 [==============================] - 93s 576ms/step - loss: 1.3929 - accuracy: 0.4538 - val_loss: 1.3897 - val_accuracy: 0.4489
# Epoch 17/20
# 161/161 [==============================] - 93s 575ms/step - loss: 1.3817 - accuracy: 0.4644 - val_loss: 1.4456 - val_accuracy: 0.4185
# Epoch 18/20
# 161/161 [==============================] - 92s 574ms/step - loss: 1.3894 - accuracy: 0.4614 - val_loss: 1.3040 - val_accuracy: 0.4555
# Epoch 19/20
# 161/161 [==============================] - 92s 573ms/step - loss: 1.3851 - accuracy: 0.4629 - val_loss: 1.6670 - val_accuracy: 0.4109
# Epoch 20/20
# 161/161 [==============================] - 92s 573ms/step - loss: 1.3807 - accuracy: 0.4612 - val_loss: 1.4817 - val_accuracy: 0.4367

# %% [markdown]
# # accuracy analysis

# %%
def get_confusion_matrix(data_path, N):
    # we need to see the data in the same order
    # for both predictions and targets
    print("Generating confusion matrix", N)
    predictions = []
    targets = []
    i = 0
    for x, y in gen.flow_from_directory(data_path, target_size=IMAGE_SIZE, shuffle=False, batch_size=batch_size * 2):
        i += 1
        if i % 50 == 0:
            print(i)
        p = model.predict(x)
        p = np.argmax(p, axis=1)
        y = np.argmax(y, axis=1)
        predictions = np.concatenate((predictions, p))
        targets = np.concatenate((targets, y))
        if len(targets) >= N:
            break

    cm = confusion_matrix(targets, predictions)
    return cm

# %%
# loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend()
plt.show()

# accuracies
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()
